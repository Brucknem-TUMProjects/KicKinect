# %%
import pandas as pd
import matplotlib as plt

# %%
recordings = 'C:\\Users\\ga58lum\\Documents\\Kickinect Simulator 2019\\Assets\\_Recordings\\Velocities\\'
date = ''#'30-Jun-2019-15-03-31'
filename = '\\velocities.csv'
frame = pd.read_csv(recordings + date + filename)
print(frame)
# Out:
#       index   velocity
# 0         0   0.000000
# 1         1   0.000000
# 2         2   0.000000
# 3         3   0.000000
# 4         4  10.239610
# 5         5   2.822304
# 6         6   1.951771
# 7         7   1.506591
# 8         8   0.871252
# 9         9   0.685767
# 10       10   0.387908
# 11       11   0.304284
# 12       12   0.263959
# 13       13   0.283967
# 14       14   0.136530
# 15       15   0.166231
# 16       16   0.370963
# 17       17   0.354382
# 18       18   0.631892
# 19       19   0.528137
# 20       20   0.452383
# 21       21   0.562177
# 22       22   0.541227
# 23       23   0.474594
# 24       24   0.263751
# 25       25   0.328948
# 26       26   0.235665
# 27       27   0.234403
# 28       28   0.222818
# 29       29   0.222610
# ...     ...        ...
# 1755   1755   0.000000
# 1756   1756   0.000000
# 1757   1757   0.000000
# 1758   1758   0.000000
# 1759   1759   0.000000
# 1760   1760   0.000000
# 1761   1761   0.000000
# 1762   1762   0.000000
# ...

# %%
frame = frame.drop(frame[frame.velocity > 30].index)
frame.plot.line(x='index', y='velocity')
